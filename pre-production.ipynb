# %% [markdown]
# # Quantum Blur Photo Booth for Science Gallery (24 Oct)
#
# This notebook is for pre-production testing of the interactive photo booth for Science Gallery. The user workflow is this:
#
# 1. The user walks up to the monitor and the webcam.
# 2. The user will see the guidance on the screen (Not recommended) or on a card right next to the monitor.
# 3. The user will increase/decrease strength of Quantum Blur. OR The user will just press a key to take a picture.
# 4. The user will see the photo is processed and printing out from the printer.
#
# What backend needs to do:
#
# 1. It must set the program (a `Python` script) to an infinite loop.
# 2. It must go back to its original state what it has been done after the photo is printed.
# 3. On the original state, it must wait for the acceptable keyboard input, A) Increase QB strength, B) Decrease QB strength, and C) Take a picture.
# 4. When there's an input of taking a picture, it must **display any countdown** on the screen for user.
# 5. After the countdown, it needs to save the image to the local storage.
# 6. From the local storage, **it must call the printer to print it.**
# 7. When the printer finishes its job, **somehow it must trigger the Python script and it must reset.**

# %%
import quantumblur as qb
import cv2
